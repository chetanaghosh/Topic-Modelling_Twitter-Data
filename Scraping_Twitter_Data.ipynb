# %%
import json
import pandas as pd

# %%
import requests

# %%
API_KEY = 'new1_5ae3f7966e8949728349b09a2a72ab37'
url = 'https://api.twitterapi.io/twitter/tweet/advanced_search'
headers = {'x-api-key': API_KEY}

params = {
    "query": "Nirbhaya rape case",  # your keywords
    "count": 100,
    "lang": "en",
    "until": "2013-01-31",
    "since": "2012-12-16"
}

response = requests.get(url, headers=headers, params=params)

data = response.json()

# %%
df = pd.DataFrame(data['tweets'])[['id','text']]

# %%
len(df)
# Out:
# 15

# %%
next_token = data.get("next_cursor")
API_KEY = 'new1_5ae3f7966e8949728349b09a2a72ab37'
url = 'https://api.twitterapi.io/twitter/tweet/advanced_search'
headers = {'x-api-key': API_KEY}

params = {
    "query": "Nirbhaya rape case",  # your keywords
    "count": 100,
    "lang": "en",
    "until": "2013-01-31",
    "since": "2012-12-16"
}

while next_token:
    params["next_cursor"] = next_token
    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    next_token = data.get("next_cursor")

# %%
df.head()
# Out:
#                     id                                               text
# 0  1983524974292824193  @DesiVicharWala In dehli Nirbhaya rape  case, ...
# 1  1983524623619936478  @Dumpyssharma @NazneenAkhtar23 Rape ki baat ho...
# 2  1983431374246945018  @TguySafe @DrNimoYadav In the context of that ...
# 3  1983122500612706573  @sauroness @Dirvewith18 @Wean__007 My apologie...
# 4  1983076637911495015  @kpilyal @venom1s Men who rape also get bail? ...
